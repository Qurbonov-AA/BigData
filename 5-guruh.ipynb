# %%
import pandas as pd
# Out:
# C:\Users\Sobir\AppData\Local\Temp\ipykernel_10600\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("insurance.csv")

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df[df.duplicated()]
# Out:
#      age   sex    bmi  children smoker     region    charges
# 581   19  male  30.59         0     no  northwest  1639.5631

# %%
df[(df["age"] == 19) & (df["sex"] == "male") & (df["bmi"] == 30.59)]
# Out:
#      age   sex    bmi  children smoker     region    charges
# 195   19  male  30.59         0     no  northwest  1639.5631
# 581   19  male  30.59         0     no  northwest  1639.5631

# %%
from matplotlib import pyplot as plt
plt.plot(df["age"], df["charges"])
plt.title("sugurta polisi")
plt.show()

# %%
df_erkak = df[df["sex"] == "male"]
df_ayol = df[df["sex"] == "female"]

# %%
plt.plot(df_erkak["age"], df_erkak["charges"])
plt.plot(df_ayol["age"], df_ayol["charges"])
plt.title("sugurta polisi")
plt.xlabel("yosh")
plt.ylabel("sug;urta summasi")
plt.show()

# %%
plt.title("sugurta polisi")
plt.xlabel("yosh")
plt.ylabel("sug;urta summasi")
plt.show()

# %%
df_chekadigan = df[df["smoker"] == "yes"]
df_chekmaydi = df[df["smoker"] == "no"]

# %%
plt.plot(df_chekadigan["age"], df_chekadigan["charges"])
plt.plot(df_chekmaydi["age"], df_chekmaydi["charges"])
plt.title("checkadigan va chekmaydiganlar")
plt.xlabel("yosh")
plt.ylabel("sug'urta summasi")
plt.show()

# %%
df_no = df[df["children"] == 0]
df_yes = df[df["children"] >= 1]

# %%
plt.plot(df_no["age"], df_no["charges"])
plt.plot(df_yes["age"], df_yes["charges"])
plt.title("farzand farqi buyicha")
plt.xlabel("yosh")
plt.ylabel("sug'urta summasi")
plt.show()
